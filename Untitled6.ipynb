# %% [markdown]
# <a href="https://colab.research.google.com/github/202235402/AI-programming/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %%
features = pd.read_csv('/content/titanic.csv', index_col = 0)

# %%
features
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# 결측치 제거

# %% [markdown]
# ##결측치 확인

# %%
features.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# #결측치 제거

# %% [markdown]
# ##결측치가 들어있는 행 제거

# %%
# delete row with missing values
features.dropna(axis=0)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ##결측치가 들어있는 열 제거

# %%
# delete column with missing values
features.dropna(axis=1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1
# 3                                       Heikkinen, Miss. Laina  female      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1
# 5                                     Allen, Mr. William Henry    male      0
# ...                                                        ...     ...    ...
# ...

# %% [markdown]
# ##특정 칼럼 또는 행에 결측값이 들어있으면 제거

# %%
#delete specific row or column with missing values
features['Age'].dropna()
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 886    39.0
# 887    27.0
# 888    19.0
# 890    26.0
# 891    32.0
# Name: Age, Length: 714, dtype: float64

# %% [markdown]
# ##적어도 하나의 결측치가 들어있다면 해당 칼럼 또는 행을 제거

# %%
features.dropna(how='any')
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
# Survived를 타겟 레이블로 삼아서 EDA 수행
# 1. Plass 레이블별 갯수 및 차트표시
# 2. 생존자와 사망자 총 숫자 및 차트표시
# 3. 성별, 티켓클래스(Pclass), 생존여부(Survived) 상관관계 분석
# 4. X_train, y_ytrain, X_test, y_test로 나누고 생존여부(Survived)에 따라 각각 분류(SVM, LR, DT, RT, KNN) 수행

# %% [markdown]
# # Survived를 타겟 레이블로 삼아서 EDA 수행

# %% [markdown]
# ##1. Pclass 레이블별 갯수 및 차트표시

# %%
plt.hist(features['Pclass'])
plt.show()

# %% [markdown]
# ## 2. 생존자와 사망자 총 숫자 및 차트표시

# %% [markdown]
# ## 3. 성별, 티켓클래스(Pclass), 생존여부(Survived) 상관관계 분석

# %%
features_pivot = pd.pivot_table(index = 'Sex', columns = 'Pclass', values = 'Survived', data = features)
features_pivot
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
sns.heatmap(features_pivot)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Sex'>

# %% [markdown]
# ## 4. X_train, y_train, X_test, y_test로 나누고 생존여부(Survived)에 따라 각각 분류(SVM, LR, DT, RT, KNN) 수행
